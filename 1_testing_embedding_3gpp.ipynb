# %%
import os
from langchain.vectorstores import Chroma
from langchain.document_loaders import UnstructuredMarkdownLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

root_db = "3gpp_db"
all_sub_dbs = [d for d in os.listdir(root_db) if os.path.isdir(os.path.join(root_db, d))]

model_name = "sentence-transformers/all-MiniLM-L6-v2"
model_kwargs = {'device': 'cuda'}
embedding = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)


all_docs = []
for sub in all_sub_dbs:
    path = os.path.join(root_db, sub)
    print(f"\n📂 載入資料庫：{sub}")

    db = Chroma(persist_directory=path, embedding_function=embedding)
    docs = db.get()["documents"]

    print(f"📄 {sub} 中共有 {len(docs)} 個 chunks\n")
    all_docs.extend(docs)

print(f"\n📦 合計讀入 {len(all_docs)} 筆 chunks")
# Out:
# 📂 載入資料庫：32111-6-g00
# 📄 32111-6-g00 中共有 853 個 chunks
#
#
# 📂 載入資料庫：32901-g00
# 📄 32901-g00 中共有 129 個 chunks
#
#
# 📂 載入資料庫：37461-g10
# 📄 37461-g10 中共有 93 個 chunks
#
#
# 📂 載入資料庫：28306-g00
# 📄 28306-g00 中共有 361 個 chunks
#
#
# 📂 載入資料庫：37571-3-ge0
# 📄 37571-3-ge0 中共有 1626 個 chunks
#
#
# 📂 載入資料庫：26978-g00
# 📄 26978-g00 中共有 313 個 chunks
#
#
# 📂 載入資料庫：22186-g20
# 📄 22186-g20 中共有 219 個 chunks
#
#
# 📂 載入資料庫：29388-g00
# 📄 29388-g00 中共有 308 個 chunks
#
#
# 📂 載入資料庫：25906-g00
# 📄 25906-g00 中共有 267 個 chunks
#
#
# 📂 載入資料庫：33516-g20
# 📄 33516-g20 中共有 48 個 chunks
#
#
# 📂 載入資料庫：36456-g00
# 📄 36456-g00 中共有 49 個 chunks
#
#
# 📂 載入資料庫：38887-g00
# 📄 38887-g00 中共有 451 個 chunks
#
#
# 📂 載入資料庫：22182-g00
# 📄 22182-g00 中共有 128 個 chunks
#
#
# 📂 載入資料庫：28516-g00
# 📄 28516-g00 中共有 68 個 chunks
#
#
# 📂 載入資料庫：26405-g00
# 📄 26405-g00 中共有 88 個 chunks
#
#
# 📂 載入資料庫：28683-g00
# 📄 28683-g00 中共有 24 個 chunks
#
#
# 📂 載入資料庫：32661-g00
# 📄 32661-g00 中共有 58 個 chunks
#
#
# 📂 載入資料庫：22031-g00
# 📄 22031-g00 中共有 100 個 chunks
#
#
# ...

# %%
import random

# 隨機選一份 spec
random_sub = random.choice(all_sub_dbs)
path = os.path.join(root_db, random_sub)

print(f"\n🎯 隨機選取：{random_sub}")
db = Chroma(persist_directory=path, embedding_function=embedding)

# 取得內容與 metadata
data = db.get()
docs = data["documents"]
metas = data["metadatas"]

# 顯示總 chunk 數
print(f"📦 共 {len(docs)} 個 chunks")

# 顯示前 200 個 chunk 細節（你可調整數量）
for i in range(min(200, len(docs))):
    print(f"\n--- Chunk {i+1} ---")
    print(f"📁 來源：{metas[i].get('path', '無')}")
    print(f"📄 spec：{metas[i].get('spec', '無')}")
    print(f"📚 內容：\n{docs[i][:500]}")  # 最多印 500 字，避免太長
# Out:
# 🎯 隨機選取：38455-gc0
# 📦 共 1293 個 chunks
#
# --- Chunk 1 ---
# 📁 來源：TSpec-LLM/Rel-16/38_series/38455-gc0.md
# 📄 spec：38455-gc0
# 📚 內容：
# 3GPP TS 38.455 V16.12.0 (2023-06)
#
# Technical Specification
#
# 3rd Generation Partnership Project;
#
# Technical Specification Group Radio Access Network;
#
# NG-RAN;
#
# NR Positioning Protocol A (NRPPa)
#
# (Release 16)
#
# --- Chunk 2 ---
# 📁 來源：TSpec-LLM/Rel-16/38_series/38455-gc0.md
# 📄 spec：38455-gc0
# 📚 內容：
# {width="1.3256944444444445in" height="0.91875in"} {width="1.7777777777777777in" height="1.0444444444444445in"}
#
# --- Chunk 3 ---
# 📁 來源：TSpec-LLM/Rel-16/38_series/38455-gc0.md
# 📄 spec：38455-gc0
# 📚 內容：
# The present document has been developed within the 3rd Generation Partnership Project (3GPP ^TM^) and may be further elaborated for the purposes of 3GPP..\ The present document has not been subject to any approval process by the 3GPP Organizational Partners and shall not be implemented.\ This
#
# --- Chunk 4 ---
# ...
